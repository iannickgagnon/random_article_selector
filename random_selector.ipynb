# %% [markdown]
# <a href="https://colab.research.google.com/github/iannickgagnon/itor_jan_23_oa_0038/blob/main/random_articles_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import numpy as np
from bs4 import BeautifulSoup

# %%
def gs_scrape(query: str, nb_pages: int = 5, year: int = None):
    """
    Scrapes a given number of pages of Google Scholar results for a given search query,
    with an optional year filter.

    Args:
        query (str): The search query.
        nb_pages (int): The number of pages to scrape.
        year (int): The publication year to filter articles by.

    Returns:
        (list): A list of articles stored as title-authors-link dictionaries.
    """
    
    # The number of results shown on each page
    NB_RESULTS_PER_PAGE = 10

    # Client identifier
    headers = {'User-Agent': 'Mozilla/5.0'}

    # Initialize container for output articles
    articles = []

    # Through each page's articles
    for page_index in range(nb_pages):
        # Results iterator
        start_index = page_index * NB_RESULTS_PER_PAGE

        # Build URL with query and year filter
        url = f"https://scholar.google.com/scholar?q={query}&hl=en&start={start_index}"
        if year:
            url += f"&as_ylo={year}&as_yhi={year}"

        # Send HTTP request
        response = requests.get(url, headers=headers)
        response.raise_for_status()

        # Parse HTTP request response as HTML
        soup = BeautifulSoup(response.content, 'html.parser')
        for result in soup.find_all('div', class_='gs_ri'):
            # Get title and authors
            title = result.find('h3', class_='gs_rt').get_text()
            authors = result.find('div', class_='gs_a').get_text()

            # Get the href attribute from the hyperlink anchor
            link_tag = result.find('a')
            link = link_tag['href'] if link_tag else None

            # Save article as dictionary
            article = {
                'title': title,
                'authors': authors,
                'link': link
            }
            # Store article in output list
            articles.append(article)

    return articles

# %%
def download_articles(articles, 
                      download_folder="downloaded_articles",
                      max_size_kb=1000):
    """
    Downloads PDFs from a list of articles if the PDF link is available and the file size is under the specified limit.

    Args:
        articles (list): List of dictionaries containing 'title', 'authors', and 'link'.
        download_folder (str): Directory to save the downloaded PDFs.

    Returns:
        None
    """

    # Ensure the download folder exists
    os.makedirs(download_folder, exist_ok=True)

    for article in articles:
        try:
            # Get the general page of the article
            response = requests.get(article['link'], headers={'User-Agent': 'Mozilla/5.0'})
            response.raise_for_status()
            
            # Parse the page to find PDF link
            soup = BeautifulSoup(response.content, 'html.parser')
            pdf_link = None

            # Look for PDF-related links
            for anchor in soup.find_all('a', href=True):
                href = anchor['href'].lower()
                text = anchor.get_text().lower()
                if ".pdf" in href or "pdf" in text or "download" in text:
                    pdf_link = anchor['href']
                    break

            if not pdf_link:
                print(f"No PDF link found for article: {article['title']}")
                continue

            # Handle relative URLs
            if not pdf_link.startswith("http"):
                pdf_link = requests.compat.urljoin(article['link'], pdf_link)

            # Check file size before downloading
            head_response = requests.head(pdf_link, headers={'User-Agent': 'Mozilla/5.0'})
            head_response.raise_for_status()

            file_size_kb = int(head_response.headers.get('Content-Length', 0)) / 1024
            if file_size_kb > max_size_kb:
                print(f"Skipped: {article['title']} (Size exceeds {max_size_kb} KB limit - {file_size_kb:.2f} KB)")
                continue

            # Download the PDF
            pdf_response = requests.get(pdf_link, headers={'User-Agent': 'Mozilla/5.0'})
            pdf_response.raise_for_status()

            # Save the PDF file
            safe_title = "".join(c if c.isalnum() else "_" for c in article['title'])
            file_path = os.path.join(download_folder, f"{safe_title}.pdf")

            with open(file_path, "wb") as pdf_file:
                pdf_file.write(pdf_response.content)

            print(f"Downloaded: {article['title']} -> {file_path}")

        except Exception as e:
            print(f"Failed to download article: {article['title']}. Error: {e}")

# %%
# The number of pages to scrape
NB_PAGES_TO_SCRAPE = 20

# The number of articles to extract in the current iteration
NB_ARTICLES = 5

# The year to filter articles by
YEAR = 2000

# The maximum size of a PDF file to download
MAX_SIZE_KB = 1000

# %%
# Fetch all articles from 10 results pages
articles = gs_scrape('metaheuristics', 
                     nb_pages=NB_PAGES_TO_SCRAPE, 
                     year=YEAR)

for article in articles:
    print(f"TITLE   : {article['title']}\n"
          f"AUTHORS : {article['authors']}\n"
          f"LINK    : {article['link']}\n\n")
# Out:
# TITLE   : Meta-heuristics: The state of the art
# AUTHORS : S Voß - Workshop on Local Search for Planning and …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/3-540-45612-0_1
#
#
# TITLE   : Solving vehicle routing problems using constraint programming and metaheuristics
# AUTHORS : BD Backer, V Furnon, P Shaw, P Kilby, P Prosser - Journal of heuristics, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1009621410177
#
#
# TITLE   : [HTML][HTML] Using metaheuristics in multiobjective resource constrained project scheduling
# AUTHORS : A Viana, JP de Sousa - European Journal of Operational Research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799001630
#
#
# TITLE   : Wisdom: A metaheuristic (pragmatic) to orchestrate mind and virtue toward excellence.
# AUTHORS : PB Baltes, UM Staudinger - American psychologist, 2000 - psycnet.apa.org
# LINK    : https://psycnet.apa.org/fulltext/2000-13324-012.html
#
#
# TITLE   : Optimization of a simplified fleet assignment problem with metaheuristics: Simulated annealing and GRASP
# AUTHORS : D Sosnowska - … and Complexity in Numerical Optimization: Continuous …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-1-4757-3145-3_27
#
#
# TITLE   : [PDF][PDF] On metaheuristic algorithms for combinatorial optimization problems
# AUTHORS : M Yagiura, T Ibaraki - The Transactions of the Institute of Electronics …, 2000 - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=9b8ed5e5f89868c14b1ef6d3b1da7084f3878d9b
#
#
# TITLE   : Metaheuristic methods for a class of the facility layout problem
# AUTHORS : A Gomes de Alvarenga, FJ Negreiros-Gomes… - Journal of intelligent …, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1008982420344
#
#
# TITLE   : Solving general ring network design problems by meta-heuristics
# AUTHORS : A Fink, G Schneidereit, S Voß - Computing Tools for Modeling …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-1-4615-4567-5_5
#
#
# TITLE   : Applying combinatorial optimization metaheuristics to the golf scramble problem
# AUTHORS : RG Dear, Z Drezner - International Transactions in Operational …, 2000 - Wiley Online Library
# LINK    : https://onlinelibrary.wiley.com/doi/abs/10.1111/j.1475-3995.2000.tb00203.x
#
#
# TITLE   : [PDF][PDF] An hybrid GRASP+ VND metaheuristic for the prize-collecting traveling salesman problem
# AUTHORS : LM Gomes, VB Diniz, CA Martinhon - XXXII Simpósio Brasileiro de …, 2000 - academia.edu
# LINK    : https://www.academia.edu/download/33292063/rt_06-00.pdf
#
#
# TITLE   : Cosearch: a co-evolutionary metaheuristic
# AUTHORS : V Bachelet, EG Talbi - Proceedings of the 2000 Congress on …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/870839/
#
#
# TITLE   : Effective heuristic and metaheuristic approaches to optimize component placement in printed circuit board assembly
# AUTHORS : EK Burke, PI Cowling, R Keuthen - Proceedings of the 2000 …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/870310/
#
#
# TITLE   : A systematic comparison of performance of various multiple objective metaheuristics using a common set of analytical test functions
# AUTHORS : Y Collette, P Siarry, HI Wong - Foundations of Computing and Decision …, 2000 - infona.pl
# LINK    : https://www.infona.pl/resource/bwmeta1.element.baztech-article-BPP1-0017-0099
#
#
# TITLE   : Optimization of water distribution systems by a tabu search metaheuristic
# AUTHORS : A Fanni, S Liberatore, GM Sechi, M Soro… - Computing Tools for …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-1-4615-4567-5_16
#
#
# TITLE   : [PDF][PDF] An adaptive hybrid metaheuristic for permutation flowshop scheduling
# AUTHORS : J Moccellin, M Santos - Control and Cybernetics, 2000 - bibliotekanauki.pl
# LINK    : https://bibliotekanauki.pl/articles/206870.pdf
#
#
# TITLE   : Global optimization and meta-heuristics
# AUTHORS : M Laguna - 2000 - books.google.com
# LINK    : https://books.google.com/books?hl=en&lr=&id=yGB8DAAAQBAJ&oi=fnd&pg=PA223&dq=metaheuristics&ots=ziSBSr-zx4&sig=K-k32d318MO6vrVnYcAKsT-emF4
#
#
# TITLE   : An object-oriented methodology for solving the RCPSPs with heuristics and metaheuristics
# AUTHORS : L Shixin, W Mengguang - Production Planning & Control, 2000 - Taylor & Francis
# LINK    : https://www.tandfonline.com/doi/abs/10.1080/09537280050051933
#
#
# TITLE   : A parallel co-evolutionary metaheuristic
# AUTHORS : V Bachelet, EG Talbi - Parallel and Distributed Processing: 15 IPDPS …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/3-540-45591-4_85
#
#
# TITLE   : Reconfiguration algorithms based on meta-heuristics for multihop WDM lightwave networks
# AUTHORS : M Kato, Y Oie - 2000 IEEE International Conference on …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/853772/
#
#
# TITLE   : [PDF][PDF] Satellite constellations optimization with metaheuristics
# AUTHORS : E Grandchamp, V Charvillat - Proceedings of Euro, 2000 - calamar.univ-ag.fr
# LINK    : http://calamar.univ-ag.fr/uag/ufrsen/coursenligne/egrandch/documents/grandchamp_euro_2000.pdf
#
#
# TITLE   : A tabu search metaheuristic for the air refueling tanker assignment problem
# AUTHORS : SR Capehart - 2000 - scholar.afit.edu
# LINK    : https://scholar.afit.edu/etd/4755/
#
#
# TITLE   : A hybrid jump search and tabu search metaheuristic for the unmanned aerial vehicle (UAV) routing problem
# AUTHORS : GW Kinney Jr - 2000 - scholar.afit.edu
# LINK    : https://scholar.afit.edu/etd/4816/
#
#
# TITLE   : Integrating orbit database and metaheuristics to design satellite constellation
# AUTHORS : E Grandchamp, V Charvillat - International Conference on Artificial …, 2000 - hal.science
# LINK    : https://hal.science/hal-00634752/
#
#
# TITLE   : [PDF][PDF] A metaheuristic (pragmatic) to orchestrate mind and virtue toward excellence
# AUTHORS : PB Baltes, UM Staudinger - American Psychologist, 2000 - pure.mpg.de
# LINK    : https://pure.mpg.de/rest/items/item_2102711/component/file_2102710/content?trk=public_post_comment-text
#
#
# TITLE   : [PDF][PDF] Fixed channel assignment in cellular communication systems considering the whole set of packed patterns. An investigation based on metaheuristics
# AUTHORS : P Borges, R Vidal - Control and Cybernetics, 2000 - bibliotekanauki.pl
# LINK    : https://bibliotekanauki.pl/articles/206293.pdf
#
#
# TITLE   : [PDF][PDF] Convergence speed in multi-objective metaheuristics: efficiency criteria and empirical study
# AUTHORS : JJ Durillo, AJ Nebro, F Luna… - Int. J. Numer …, 2000 - delta.cs.cinvestav.mx
# LINK    : http://delta.cs.cinvestav.mx/~ccoello/journals/durillo-ijnme2010.pdf.gz
#
#
# TITLE   : Meta-heuristics: advances and trends in local search paradigms for optimization
# AUTHORS : JD Pinter - Interfaces, 2000 - go.gale.com
# LINK    : https://go.gale.com/ps/i.do?id=GALE%7CA69005610&sid=googleScholar&v=2.1&it=r&linkaccess=abs&issn=00922102&p=AONE&sw=w
#
#
# TITLE   : [HTML][HTML] Experimental evaluation of state-of-the-art heuristics for the resource-constrained project scheduling problem
# AUTHORS : S Hartmann, R Kolisch - European journal of operational research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799004853
#
#
# TITLE   : [PDF][PDF] Decision Strategies based on Metaheuristics for Distribution Network Planning
# AUTHORS : TP Leão, JA Dominguez-Navarro, I Ramirez-Rosado… - 2000 - repositorio.inesctec.pt
# LINK    : http://repositorio.inesctec.pt/bitstream/123456789/1232/1/PS-00098.pdf
#
#
# TITLE   : [PDF][PDF] S. Voss, S. Martello, IH Osman, C. Roucairol (sous la direction de)," Meta-heuristics: advances and trends in local search paradigms for optimization", Boston …
# AUTHORS : O Hudry - … et sciences humaines. Mathematics and social …, 2000 - journals.openedition.org
# LINK    : https://journals.openedition.org/msh/pdf/2836
#
#
# TITLE   : [PDF][PDF] A method combining interior point methods and metaheuristics for 0-1 programming
# AUTHORS : A Plateau, P Tolla - CLAIO'00 Mexico, 2000 - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=95e49eb418ca1fd664b0e757989ce47ab6e0c0b8
#
#
# TITLE   : [PDF][PDF] Simulation-based optimization in the automotive industry-A case study on body shop design
# AUTHORS : S Spieckermann, K Gutenschwager, H Heinzel… - Simulation-California …, 2000 - simplan.de
# LINK    : https://www.simplan.de/wp-content/uploads/2000_12_Simulation_EN.pdf
#
#
# TITLE   : [PDF][PDF] A Metaheuristic Approach to Evaluate Long Term Marginal Prices and the Impact of Uncertainties and Regulatory Decisions
# AUTHORS : TP Le - 2000 - repositorio.inesctec.pt
# LINK    : http://repositorio.inesctec.pt/bitstream/123456789/3008/1/PS-00099.pdf
#
#
# TITLE   : [CITATION][C] Meta-heuristics for the deterministic hybrid flow shop problem
# AUTHORS : M Gourgand, N Grangeon… - Journal européen des …, 2000 - pascal-francis.inist.fr
# LINK    : https://pascal-francis.inist.fr/vibad/index.php?action=getRecordDetail&idt=5668626
#
#
# TITLE   : An annotated overview of system-reliability optimization
# AUTHORS : W Kuo, VR Prasad - IEEE Transactions on reliability, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/877336/
#
#
# TITLE   : [CITATION][C] Metaheuristics and combinatorial optimization problems. M
# AUTHORS : GS Scriptor - 2000 - thesis, University of Buffalo
# LINK    : javascript:void(0)
#
#
# TITLE   : [PDF][PDF] A general software library for parallel simulated annealing
# AUTHORS : G Kliewer - … of EURO Winter Institute on Metaheuristics in …, 2000 - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=aabfa5cb1b26e4435418150e17149e1c1a5070e4
#
#
# TITLE   : [CITATION][C] Metaheuristic approaches for the pure flowshop manufacturing cell problem
# AUTHORS : PM Franca, JD Gupta, A Mendes, P Moscato, KJ Veltink - 7th International Workshop …, 2000
# LINK    : /citations?user=oaHRFfAAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [CITATION][C] Monitors for GLS and other Meta-heuristics”
# AUTHORS : P Mills - Department of Computer Science, University of Essex, 2000
# LINK    : /citations?user=igLuhKgAAAAJ&hl=en&oi=sra
#
#
# TITLE   : A study of the hybridization of meta-heuristics, application to a jobshop scheduling problem
# AUTHORS : D Duvivier - 2000 - policycommons.net
# LINK    : https://policycommons.net/artifacts/15846601/a-study-of-the-hybridization-of-meta-heuristics-application-to-a-jobshop-scheduling-problem/16737460/
#
#
# TITLE   : Ant colony optimization for the total weighted tardiness problem
# AUTHORS : M Den Besten, T Stützle, M Dorigo - … Problem Solving from Nature PPSN VI …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/3-540-45356-3_60
#
#
# TITLE   : [CITATION][C] Special issue: Multiple objective metaheuristics
# AUTHORS : X Gandibleux, A Jaszkiewicz, A Freville, R Slowinski - Journal of Heuristics, 2000
# LINK    : /citations?user=2Vn54XIAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [HTML][HTML] An interactive heuristic method for multi-objective combinatorial optimization
# AUTHORS : J Teghem, D Tuyttens, EL Ulungu - Computers & Operations Research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0305054899001094
#
#
# TITLE   : Optimized Search Heuristics
# AUTHORS : H Ramalhinho - 2000 - ideas.repec.org
# LINK    : https://ideas.repec.org/p/sce/scecf0/250.html
#
#
# TITLE   : [PDF][PDF] Integrating optimization and simulation: research and practice
# AUTHORS : MC Fu, S Andradóttir, JS Carson, F Glover… - Winter Simulation …, 2000 - researchgate.net
# LINK    : https://www.researchgate.net/profile/Fred-Glover/publication/234818233_Integrating_optimization_and_simulation_research_and_practice/links/0fcfd5110027090bba000000/Integrating-optimization-and-simulation-research-and-practice.pdf
#
#
# TITLE   : A tabu search approach to cellular manufacturing systems
# AUTHORS : GC Onwubolu, V Songore - Production planning & control, 2000 - Taylor & Francis
# LINK    : https://www.tandfonline.com/doi/abs/10.1080/095372800232351
#
#
# TITLE   : [CITATION][C] Metaheuristics for multiobjective combinatorial optimization: state of the art
# AUTHORS : EG Talbi - LIFL, Lille, France, Tech. Rep, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] A HYBRID JUMP SEARCH AND TABU SEARCH METAHEURISTIC FOR THE UNMANNED AERIAL VEHICLE (UAV) ROUTING PROBLEM THESIS
# AUTHORS : GW Kinney Jr
# LINK    : javascript:void(0)
#
#
# TITLE   : [HTML][HTML] An ANTS heuristic for the frequency assignment problem
# AUTHORS : V Maniezzo, A Carbonaro - Future Generation Computer Systems, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0167739X00000467
#
#
# TITLE   : [CITATION][C] The Application of Metaheuristic Search Techniques to Problems in Software Engineering
# AUTHORS : J Clarke, M Harman, R Hierons, B Jones, M Lumkin… - … using Metaheuristic …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Decision strategies based on metaheuristics for Distribution Networks Planning
# AUTHORS : MTP De Leão, M Matos, JA Dominguez-Navarro… - 6th PMAPS Conference …, 2000
# LINK    : /citations?user=r4Qv7DkAAAAJ&hl=en&oi=sra
#
#
# TITLE   : Classical and modern heuristics for the vehicle routing problem
# AUTHORS : G Laporte, M Gendreau, JY Potvin… - … in operational research, 2000 - Wiley Online Library
# LINK    : https://onlinelibrary.wiley.com/doi/abs/10.1111/j.1475-3995.2000.tb00200.x
#
#
# TITLE   : Variable neighborhood search for extremal graphs: 1 The AutoGraphiX system
# AUTHORS : G Caporossi, P Hansen - Discrete Mathematics, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0012365X9900206X
#
#
# TITLE   : [CITATION][C] The Ant Colony Optimization Metaheuristic: Algorithm, Applications
# AUTHORS : M Dorigo, T Stützle - … ., Kochenberger, GA (eds.) Handbook of Metaheuristics, 2000
# LINK    : /citations?user=OrODXkAAAAAJ&hl=en&oi=sra
#
#
# TITLE   : A general parallel simulated annealing library and its application in airline industry
# AUTHORS : G Kliewer, S Tschoke - Proceedings 14th International Parallel …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/845964/
#
#
# TITLE   : [CITATION][C] Metaheuristics for Distributed File and Task Placement Problem
# AUTHORS : M ŠEDA
# LINK    : /citations?user=aBYMXXYAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [CITATION][C] Vehicle Routing Problems (VRPs), Metaheuristics Network
# AUTHORS : LM Gambardella - 2000 - Technische Universiteit Eindhoven …
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Variable neighborhood search for the traveling purchacer problem
# AUTHORS : MB Silva, L Drummond, LS Ochi - 27th Int. Conference on Computational Industrial …, 2000
# LINK    : /citations?user=UhYdnvYAAAAJ&hl=en&oi=sra
#
#
# TITLE   : Autographix: An automated system for finding conjectures in graph theory
# AUTHORS : P Hansen, G Caporossi - Electronic Notes in Discrete Mathematics, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S1571065305801519
#
#
# TITLE   : [CITATION][C] School timetabling: an approximation by metaheuristics
# AUTHORS : MJF Souza - 2000 - … Federal University of Rio de Janeiro …
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Timetabling in high-schools: approximation by metaheuristics
# AUTHORS : M Souza - 2000 - … Federal do Rio de Janeiro, Brazil
# LINK    : javascript:void(0)
#
#
# TITLE   : [PDF][PDF] Solving permutation constraint satisfaction problems with artificial ants
# AUTHORS : C Solnon - ECAI, 2000 - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=2c4a8c2f7f28c4412f1f143d96383044f7e32c01
#
#
# TITLE   : A comparison of optimization techniques for Loney's solenoids design: An alternative tabu search algorithm
# AUTHORS : E Cogotti, A Fanni, F Pilo - IEEE transactions on magnetics, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/877645/
#
#
# TITLE   : [CITATION][C] Metaheuristics for the hybrid flowshop problem
# AUTHORS : M Gourgand, N Grangeon, S Norre - 2000 - RAIRO-APII-JESA
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Efficient solutions of the general heterogeneous fleet vehicle routing problem via novel threshold acceptance metaheuristics
# AUTHORS : CD Tarantilis, CT Kiranoudis, VS Vassiliadis - AIChE Annual Meeting, Los Angeles …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [PDF][PDF] Iterated local search
# AUTHORS : H Ramalhinho-Lourenço, OC Martin, T Stützle - 2000 - repositori.upf.edu
# LINK    : https://repositori.upf.edu/bitstream/handle/10230/1243/513.pdf?sequence=1
#
#
# TITLE   : [CITATION][C] Bibliographie critique:-Metaheuristics: Advances and trends in local search paradigms for optimization
# AUTHORS : S Voss, S Martello, IH Osman… - …, 2000 - [Paris]: Editions de l'Ecole des …
# LINK    : /citations?user=PuMO0YsAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [CITATION][C] Three Methods to Automate the Space Allocation Process in UK Universities EK Burke', P. Cowling', JD Landa Silva", and Barry McCollum²'Automated …
# AUTHORS : B EK - Practice and Theory of Automated Timetabling, 2000 - Springer
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Optimization of a simplified fleet assignment problem with metaheuristics: Simulated annealing and GRASP. PM Pardalos, ed. Approximation and …
# AUTHORS : D Sosnowska - 2000 - Kluwer Academic Publishers …
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Supply chain management: an opportunity for metaheuristics
# AUTHORS : RL Helena - Proceedings of International Conference on Adaptive …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : Competitive genetic algorithms for the open-shop scheduling problem
# AUTHORS : C Prins - Mathematical methods of operations research, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1007/s001860000090
#
#
# TITLE   : [CITATION][C] Meta-heuristics: The State of the Art. Local Search for Planning and Scheduling
# AUTHORS : V Stefan - ECAI 2000 Workshop. Springer, Germany (August 21 …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Wisdom: a metaheuristic (pragmatic) to orchestate mind and wisdom towards excellence
# AUTHORS : P Balthes, U Staudinger - American psychologist, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : An interactive method for 0-1 multiobjective problems using simulated annealing and tabu search
# AUTHORS : MJ Alves, J Clímaco - Journal of Heuristics, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1009686616612
#
#
# TITLE   : [CITATION][C] A survey for metaheuristic algorithms
# AUTHORS : J Digalakis, K Margaritis - 2000 - Internal Report
# LINK    : /citations?user=YAzF48oAAAAJ&hl=en&oi=sra
#
#
# TITLE   : CHESS—Changing Horizon Efficient Set Search: A simple principle for multiobjective optimization
# AUTHORS : PC Borges - Journal of Heuristics, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1009638700683
#
#
# TITLE   : [CITATION][C] Group theory and metaheuristic search neighborhoods. Graduate Program in Operations Research
# AUTHORS : B Colletti, JW Barnes - 2000 - … Series 2000-03, The University of …
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Wisdom: a metaheuristic (pragmatic) to orchestrate mind and virtue towards excellence.“
# AUTHORS : SU B PB - 2000 - American Psychologyst
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Meta-heuristics: The state of the Art. Local Search for Planning and Scheduling. Edited by A. Nareyek, ECAI 2000 Workshop
# AUTHORS : S Vos - 2000 - Springer-Verlag, Germany
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] A new hybrid evolutionary algorithm for the vehicle routing problem with time windows
# AUTHORS : O Bräysy, J Berger, M Barkaoui - Route 2000 Workshop, Skodsborg, Denmark, 2000
# LINK    : /citations?user=TGeQUCgAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [CITATION][C] A study on Developing algorithms for Manufacturing networks using meta-Heuristics
# AUTHORS : YS Lee - 2000 - Ph. D. Thesis, Sangmyung …
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Barnes and DL Neuway" Using Group Theory and Transition Matrices to study a class of Metaheuristic Neighborhoods
# AUTHORS : BJW Colletti - Graduate program in operation research, technical …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Multiple Objective MetaHeuristics
# AUTHORS : X Gandibleux, A Jaszkiewicz, A Fréville, R Slowinski - 2000 - hal.science
# LINK    : https://hal.science/hal-00470391/
#
#
# TITLE   : [CITATION][C] … Search Heuristics in Multiple Objective Optimization-A systematic comparison of performance of various multiple objective metaheuristics using a common …
# AUTHORS : A Jaszkiewicz, Y Collette… - Foundations …, 2000 - Poznan, Poland: Institute of …
# LINK    : /citations?user=CmaPeOkAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [CITATION][C] Wisdom: A metaheuristic (pragmatic) to
# AUTHORS : PB Baltes, UM Staudinger - 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Wisdom: A metaheuristic (pragmatic) to orchestrate mind and virtue toward excellence. American Psychologist, 55 (1). Рр
# AUTHORS : PB Baltes, U Staudinger - 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] Tabu Search metaheuristic for water distribution system optimization
# AUTHORS : A Fanni, S Liberatore, G Sechi, M Soro… - … TOOLS FOR MODELING …, 2000 - iris.unica.it
# LINK    : https://iris.unica.it/handle/11584/8007
#
#
# TITLE   : Effectiveness of Hierarchical Connection for the Parallel and Distributed Genetic Algorithm
# AUTHORS : 松村隆， マツムラタカシ… - 沖縄大学マルチ …, 2000 - okinawauniversity.repo.nii.ac.jp
# LINK    : https://okinawauniversity.repo.nii.ac.jp/?action=pages_view_main&active_action=repository_view_main_item_detail&item_id=922&item_no=1&page_id=13&block_id=21
#
#
# TITLE   : [CITATION][C] A Metaheuristic Approach to Evaluate Long Term Marginal Prices and the Impact of Uncertainties and Regulatory Decisions
# AUTHORS : JT Saraiva, TP Leão - 2000 - repositorio.inesctec.pt
# LINK    : https://repositorio.inesctec.pt/items/edc45919-9d8b-4420-8def-6ac491aa5b85
#
#
# TITLE   : [CITATION][C] How combining interior point methods and metaheuristics for multiconstraint knapsack problem
# AUTHORS : A Plateau, D Tachat, P Tolla - 17th Int. Symp. on Mathematical …, 2000 - hal.science
# LINK    : https://hal.science/hal-01125521/
#
#
# TITLE   : [CITATION][C] Two-dimensional packing utilising evolutionary algorithms and other metaheuristic methods (Doctoral dissertation, University of Wales. Cardiff)
# AUTHORS : E Hopper - 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : A parallel tabu search based method for determining optimal allocation of FACTS in power systems
# AUTHORS : H Mori, Y Goto - … 2000. 2000 International Conference on Power …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/897170/
#
#
# TITLE   : Fuzzy global optimization of complex system reliability
# AUTHORS : V Ravi, PJ Reddy… - IEEE Transactions on …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/855914/
#
#
# TITLE   : [CITATION][C] Task scheduling heuristics in a distributive environment
# AUTHORS : J Bohm - … Science Discipline Seminar Conference, University of …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : Pareto simulated annealing for fuzzy multi-objective combinatorial optimization
# AUTHORS : M Hapke, A Jaszkiewicz, R Słowiński - Journal of heuristics, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1009678314795
#
#
# TITLE   : [CITATION][C] Metaheuristic Algorithm for the Vehicle Routing Problem with Time Windows
# AUTHORS : Z Jin - Proceedings of the 5th International Symposium on …, 2000 - cir.nii.ac.jp
# LINK    : https://cir.nii.ac.jp/crid/1572824500025585792
#
#
# TITLE   : [CITATION][C] Meta-heuristics and Heuristics for Production and Operations Management: IEPM'99
# AUTHORS : A Artiba - 2000 - pascal-francis.inist.fr
# LINK    : https://pascal-francis.inist.fr/vibad/index.php?action=getRecordDetail&idt=211426
#
#
# TITLE   : [BOOK][B] The product line pricing and positioning problem: A meta-heuristic approach
# AUTHORS : KB Nichols - 2000 - search.proquest.com
# LINK    : https://search.proquest.com/openview/2b29ec524dd02178cd090d99a3e1132f/1?pq-origsite=gscholar&cbl=18750&diss=y
#
#
# TITLE   : A Development Framework for Nature Analogic Heuristics
# AUTHORS : M Feldmann - Classification and Information Processing at the Turn of …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-3-642-57280-7_21
#
#
# TITLE   : [PDF][PDF] INTEGRATING OPTIMIZATION AND SIMULATION: RESEARCH AND PRACTICE
# AUTHORS : JA Joines, RR Barton, K Kang, PA Fishwick - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=522aa0a4faa7362767a54b39143ceb04b953582f
#
#
# TITLE   : Fundamentals of scatter search and path relinking
# AUTHORS : F Glover, M Laguna, R Martí - Control and cybernetics, 2000 - infona.pl
# LINK    : https://www.infona.pl/resource/bwmeta1.element.baztech-article-BAT2-0001-0558?&locale=pl
#
#
# TITLE   : [CITATION][C] Graphical Modelling with Interior-Point Methods and Combinatorial Optimization Techniques
# AUTHORS : A Ohara, T Tsuchiya - The Institute of Statistical Mathematics, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [CITATION][C] A Federated Architecture for Autonomous Optimization Centers.
# AUTHORS : FL Dotti, C Maurício de O, CM da Costa, FM Müller - PDPTA, 2000
# LINK    : /citations?user=mwe43TsAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [CITATION][C] Metaheuristic techniques and neuropsychological classification of schizophrenia
# AUTHORS : M Rozenthal, N Macaulan, D Habil, DD Lages… - Schizophrenia …, 2000 - infona.pl
# LINK    : https://www.infona.pl/resource/bwmeta1.element.elsevier-35852527-1e9f-31c7-9f19-ff82a917dc5e
#
#
# TITLE   : A parallel GRASP for the Steiner tree problem in graphs using a hybrid local search strategy
# AUTHORS : SL Martins, MGC Resende, CC Ribeiro… - Journal of Global …, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1026546708757
#
#
# TITLE   : [HTML][HTML] A graph-based ant system and its convergence
# AUTHORS : WJ Gutjahr - Future generation computer systems, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0167739X00000443
#
#
# TITLE   : Case‐based reasoning and improved adaptive search for project scheduling
# AUTHORS : A Schirmer - Naval Research Logistics (NRL), 2000 - Wiley Online Library
# LINK    : https://onlinelibrary.wiley.com/doi/abs/10.1002/(SICI)1520-6750(200004)47:3%3C201::AID-NAV2%3E3.0.CO;2-L
#
#
# TITLE   : A statistical analysis of simulated annealing applied to the p-median problem
# AUTHORS : F Chiyoshi, RD Galvão - Annals of Operations Research, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1018982914742
#
#
# TITLE   : Statistical analysis of computational tests of algorithms and heuristics
# AUTHORS : M Coffin, MJ Saltzman - INFORMS Journal on Computing, 2000 - pubsonline.informs.org
# LINK    : https://pubsonline.informs.org/doi/abs/10.1287/ijoc.12.1.24.11899
#
#
# TITLE   : [CITATION][C] Applying iterated local search to the permutation flow shop problem
# AUTHORS : F Intellektik, TH Darmstadt, T Stutzle - Handbook of Metaheuristics, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [PDF][PDF] Tabu search-a guided tour
# AUTHORS : M Hindsberger, R Vidal - Control and Cybernetics, 2000 - bibliotekanauki.pl
# LINK    : https://bibliotekanauki.pl/articles/205563.pdf
#
#
# TITLE   : [PDF][PDF] Automated Neural Model Design for a CSTR Using a Tabu Search Algorithm
# AUTHORS : B Cannas, A Fanni, M Marchesi, F Pilo - 2000 - academia.edu
# LINK    : https://www.academia.edu/download/70276014/download.pdf
#
#
# TITLE   : Solving the discrete-continuous project scheduling problem via its discretization
# AUTHORS : J Józefowska, M Mika, R Różycki, G Waligóra… - … Methods of Operations …, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1007/s001860000094
#
#
# TITLE   : [CITATION][C] Advances in Intelligent Systems: 2214 221 Theory and Applications M. Mohammadian (Ed.) IOS Press, 2000
# AUTHORS : H Mori, M Takahashi - Advances in Intelligent Systems: Theory and …, 2000 - IOS Press
# LINK    : /citations?user=8MLe7bsAAAAJ&hl=en&oi=sra
#
#
# TITLE   : Fitness landscape analysis and memetic algorithms for the quadratic assignment problem
# AUTHORS : P Merz, B Freisleben - IEEE transactions on evolutionary …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/887234/
#
#
# TITLE   : [HTML][HTML] Application of the noising method to the travelling salesman problem
# AUTHORS : I Charon, O Hudry - European Journal of Operational Research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799004579
#
#
# TITLE   : Environmental supply-chain management as cost driver: more than the environmental performance of the material flow
# AUTHORS : MH Nagel - Proceedings of the 2000 information resources …, 2000 - dl.acm.org
# LINK    : https://dl.acm.org/doi/abs/10.5555/352040.353618
#
#
# TITLE   : An ant colony system hybridized with a new local search for the sequential ordering problem
# AUTHORS : LM Gambardella, M Dorigo - INFORMS Journal on …, 2000 - pubsonline.informs.org
# LINK    : https://pubsonline.informs.org/doi/abs/10.1287/ijoc.12.3.237.12636
#
#
# TITLE   : [CITATION][C] Combinatorial optimization heuristics in partitioning with non euclidean distances
# AUTHORS : A Murillo, E Piza, J Trejos - Preprint, CIMPA, San José, 2000
# LINK    : /citations?user=AWMHvCUAAAAJ&hl=en&oi=sra
#
#
# TITLE   : [CITATION][C] An Exact and a Meta-heuristic Method for Optimum Resource Allocation in Clashing LEO Satellite Visibility Windows
# AUTHORS : P Soma, JD Rao, S Venkateswarlu, SK Santhalakshmi… - Indian Society of Remote …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : A simplex-based tabu search method for capacitated network design
# AUTHORS : TG Crainic, M Gendreau… - INFORMS journal on …, 2000 - pubsonline.informs.org
# LINK    : https://pubsonline.informs.org/doi/abs/10.1287/ijoc.12.3.223.12638
#
#
# TITLE   : [CITATION][C] New Approaches to Simultaneous State Observation and Parameter Estimation for Biotechnological Processes
# AUTHORS : H Valdés, G Acuña, D Bassi, R Pérez, JM Flaus - Proceedings of Controlo'2000 …, 2000
# LINK    : /citations?user=1bKq5i8AAAAJ&hl=en&oi=sra
#
#
# TITLE   : [HTML][HTML] Heuristic methods for cost-oriented assembly line balancing: A survey
# AUTHORS : M Amen - International Journal of Production Economics, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S092552739900095X
#
#
# TITLE   : [CITATION][C] Metaheuristic algorithms for water distribution systems optimization
# AUTHORS : S Liberatore, G Sechi, P Zuddas - Atti di IDRA 2000–XXVII Convegno di Idraulica e …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [PDF][PDF] Full design of robust optical networks
# AUTHORS : F Glenstrup, C Fenger, TJK Stidsen - Fifteenth Nordic Teletraffic Seminar, 2000 - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=de99e68d4026d82baf62e3014eb749f11596d132
#
#
# TITLE   : Rolling-horizon lot-sizing when set-up times are sequence-dependent
# AUTHORS : AR Clark, SJ Clark - International Journal of Production Research, 2000 - Taylor & Francis
# LINK    : https://www.tandfonline.com/doi/abs/10.1080/00207540050028106
#
#
# TITLE   : Tabu Search for target-radar assignment
# AUTHORS : M Hindsberger, R Vidal - Control and Cybernetics, 2000 - infona.pl
# LINK    : https://www.infona.pl/resource/bwmeta1.element.baztech-article-BAT2-0001-1738
#
#
# TITLE   : A parallel tabu search and its hybridization with genetic algorithms
# AUTHORS : T Matsumura, M Nakamura, S Tamaki… - … and Networks. I-SPAN …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/900254/
#
#
# TITLE   : [HTML][HTML] On the classification of NP-complete problems in terms of their correlation coefficient
# AUTHORS : E Angel, V Zissimopoulos - Discrete Applied Mathematics, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0166218X99001389
#
#
# TITLE   : Selecting a good configuration of one-way and two-way routes using tabu search
# AUTHORS : Z Drezner, S Salhi - Control and Cybernetics, 2000 - infona.pl
# LINK    : https://www.infona.pl/resource/bwmeta1.element.baztech-article-BAT2-0001-1572
#
#
# TITLE   : Reactive GRASP: An application to a matrix decomposition problem in TDMA traffic assignment
# AUTHORS : M Prais, CC Ribeiro - INFORMS Journal on Computing, 2000 - pubsonline.informs.org
# LINK    : https://pubsonline.informs.org/doi/abs/10.1287/ijoc.12.3.164.12639
#
#
# TITLE   : Designing forest landscape management
# AUTHORS : E Baskent, GA Jordan, AMM Nurullah - Forestry Chronicle, 2000 - avesis.ktu.edu.tr
# LINK    : https://avesis.ktu.edu.tr/yayin/276bf073-2859-45f1-b27a-759bb6d593e7/designing-forest-landscape-management
#
#
# TITLE   : A rule-based tabu search technique for power system decomposition
# AUTHORS : M Mori, O Matsuzaki - 2000 Power Engineering Society …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/866952/
#
#
# TITLE   : Automated recurrent neural network design to model the dynamics of complex systems
# AUTHORS : R Baratti, B Cannas, A Fanni, F Pilo - Neural Computing & Applications, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1007/s005210070012
#
#
# TITLE   : Hybrid genetic algorithms for scheduling bus and train drivers
# AUTHORS : RSK Kwan, A Wren, ASK Kwan - Proceedings of the 2000 …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/870308/
#
#
# TITLE   : Parallel tabu search for capacitor placement in radial distribution systems
# AUTHORS : H Mori, Y Ogita - 2000 IEEE Power Engineering Society Winter …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/847172/
#
#
# TITLE   : [HTML][HTML] Ant algorithms and stigmergy
# AUTHORS : M Dorigo, E Bonabeau, G Theraulaz - Future generation computer systems, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0167739X0000042X
#
#
# TITLE   : [PDF][PDF] Empirical study of Simulated Annealing aimed at improved multiobjective optimization
# AUTHORS : E Triki, Y Collette, P Siarry - 2000 - researchgate.net
# LINK    : https://www.researchgate.net/profile/Patrick-Siarry/publication/265288492_Empirical_study_of_Simulated_Annealing_aimed_at_improved_multiobjective_optimization/links/5489bde30cf225bf669c7219/Empirical-study-of-Simulated-Annealing-aimed-at-improved-multiobjective-optimization.pdf
#
#
# TITLE   : [CITATION][C] Fuzzy set approach to multi-objective and multi-mode project scheduling under uncertainty
# AUTHORS : M Hapke, R Slowinski - Scheduling Under Fuzziness. Physica-Verlag …, 2000
# LINK    : /citations?user=yCX-JrQAAAAJ&hl=en&oi=sra
#
#
# TITLE   : Simple heuristics for the two machine openshop problem with blocking
# AUTHORS : MJ Yao, H Soewandi… - Journal of the Chinese …, 2000 - Taylor & Francis
# LINK    : https://www.tandfonline.com/doi/abs/10.1080/10170669.2000.10432874
#
#
# TITLE   : [PDF][PDF] The assembly line balancing problem solved by hybrid heuristic procedures and driven exploration
# AUTHORS : J Bautista, M Mateo, R Ferrer, J Pereira… - POMS …, 2000 - researchgate.net
# LINK    : https://www.researchgate.net/profile/Joaquin-Bautista-Valhondo/publication/258217848_The_Assembly_Line_Balancing_Problem_solved_by_Hybrid_Heuristic_Procedures_and_Driven_Exploration/links/00b7d5274f24a3fbeb000000/The-Assembly-Line-Balancing-Problem-solved-by-Hybrid-Heuristic-Procedures-and-Driven-Exploration.pdf
#
#
# TITLE   : Intelligent tools in a real-world DMS environment
# AUTHORS : V Miranda, M Matos, JP Lopes… - … Meeting (Cat. No …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/867591/
#
#
# TITLE   : [PDF][PDF] Flexible Assembly Job Shop Scheduling Based on Tabu Search
# AUTHORS : JH Weng, H Okubo, H Onari - Dept. of Industrial & Management …, 2000 - researchgate.net
# LINK    : https://www.researchgate.net/profile/Jiahua-Weng/publication/267200415_Flexible_Assembly_Job_Shop_Scheduling_Based_on_Tabu_Search/links/571d6c6c08ae7f552a48f641/Flexible-Assembly-Job-Shop-Scheduling-Based-on-Tabu-Search.pdf
#
#
# TITLE   : [PDF][PDF] An ant colony approach to the bandwidth packing problem
# AUTHORS : AW Smith - 2000 - dashboard.digital.auraria.edu
# LINK    : https://dashboard.digital.auraria.edu/downloads/7e7b17f6-9354-4ac9-a0f3-f5910ffc469f
#
#
# TITLE   : [CITATION][C] Efficient Channel Assignment Algorithm under Cochannel and Adjacent
# AUTHORS : A Dawood, MM Oo, K Ahmed… - IEEE …, 2000 - Institute of Electrical and Electronics …
# LINK    : javascript:void(0)
#
#
# TITLE   : [HTML][HTML] Lot streaming and scheduling heuristics for m-machine no-wait flowshops
# AUTHORS : S Kumar, TP Bagchi, C Sriskandarajah - Computers & Industrial …, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0360835200000358
#
#
# TITLE   : Tabu search for scheduling on identical parallel machines to minimize mean tardiness
# AUTHORS : VA Armentano, DS Yamashita - Journal of intelligent manufacturing, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1008918229511
#
#
# TITLE   : [HTML][HTML] On how Pachycondyla apicalis ants suggest a new search algorithm
# AUTHORS : N Monmarché, G Venturini, M Slimane - Future generation computer …, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0167739X00000479
#
#
# TITLE   : [PDF][PDF] Scheduling a single machine where setup times are sequence dependent using an ant-colony heuristic
# AUTHORS : C Gagné, M Gravel, W Price - Abstract proceedings of ANTS, 2000 - researchgate.net
# LINK    : https://www.researchgate.net/profile/Caroline-Gagne/publication/228603702_Scheduling_a_single_machine_where_setup_times_are_sequence_dependent_using_an_ant-colony_heuristic/links/02e7e524d62c2d09ff000000/Scheduling-a-single-machine-where-setup-times-are-sequence-dependent-using-an-ant-colony-heuristic.pdf
#
#
# TITLE   : Use of substitute scalarizing functions to guide a local search based heuristic: The case of moTSP
# AUTHORS : MP Hansen - Journal of heuristics, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1009690717521
#
#
# TITLE   : A beam search based algorithm to solve flowshop scheduling problems with constraints on shared resources
# AUTHORS : CAS Passos - IFAC Proceedings Volumes, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S1474667017394843
#
#
# TITLE   : Fitness landscapes, memetic algorithms, and greedy operators for graph bipartitioning
# AUTHORS : P Merz, B Freisleben - Evolutionary Computation, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/6788134/
#
#
# TITLE   : Solving multi-objective production scheduling problems with tabu search
# AUTHORS : T Loukil, J Teghem, P Fortemps - Control and Cybernetics, 2000 - yadda.icm.edu.pl
# LINK    : https://yadda.icm.edu.pl/baztech/element/bwmeta1.element.baztech-article-BAT2-0001-1616
#
#
# TITLE   : [PDF][PDF] Convergence of variable neighborhood search
# AUTHORS : J Brimberg, P Hansen, N Mladenovic - Les Cahiers du GERAD ISSN, 2000 - gerad.ca
# LINK    : https://www.gerad.ca/fr/papers/G-2002-21.pdf
#
#
# TITLE   : [HTML][HTML] Bidirectional planning: improving priority rule-based heuristics for scheduling resource-constrained projects
# AUTHORS : R Klein - European Journal of Operational Research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799003471
#
#
# TITLE   : Heuristic algorithms
# AUTHORS : HA Eiselt, CL Sandblom, HA Eiselt… - Integer Programming and …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-3-662-04197-0_11
#
#
# TITLE   : Design of stacked self-healing rings using a genetic algorithm
# AUTHORS : M Armony, JG Klincewicz, H Luss… - Journal of HEURISTICS, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1009665726946
#
#
# TITLE   : Evaluation of multidisciplinary design optimization techniques as applied to spacecraft design
# AUTHORS : ER Taylor - … IEEE Aerospace Conference. Proceedings (Cat. No …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/879413/
#
#
# TITLE   : Efficient channel assignment algorithm under cochannel and adjacent channel interference constraint
# AUTHORS : A Dawood, MM Oo, K Ahmed… - 2000 IEEE International …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/905851/
#
#
# TITLE   : A genetic algorithm for bicriteria scheduling problems
# AUTHORS : H Morita - Journal of economics, business and law, 2000 - omu.repo.nii.ac.jp
# LINK    : https://omu.repo.nii.ac.jp/?action=pages_view_main&active_action=repository_view_main_item_detail&item_id=926&item_no=1&page_id=13&block_id=21
#
#
# TITLE   : A survey of simulation optimization techniques and procedures
# AUTHORS : JR Swisher, PD Hyden, SH Jacobson… - … Proceedings (Cat. No …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/899706/
#
#
# TITLE   : [HTML][HTML] Tabu search applied to global optimization
# AUTHORS : R Chelouah, P Siarry - European journal of operational research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799002556
#
#
# TITLE   : [PDF][PDF] Structure, duality, and randomization: Common themes in AI and OR
# AUTHORS : CP Gomes - AAAI/IAAI, 2000 - cdn.aaai.org
# LINK    : https://cdn.aaai.org/AAAI/2000/AAAI00-210.pdf
#
#
# TITLE   : TLS: A tabu search based scheduling algorithm for behavioral synthesis of functional pipelines
# AUTHORS : I Ahmad, MK Dhodhi, FM Ali - The Computer Journal, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/8129707/
#
#
# TITLE   : A group theoretic tabu search approach to the traveling salesman problem
# AUTHORS : SN Hall - 2000 - scholar.afit.edu
# LINK    : https://scholar.afit.edu/etd/4797/
#
#
# TITLE   : The effects of coefficient correlation structure in two-dimensional knapsack problems on solution procedure performance
# AUTHORS : RR Hill, CH Reilly - Management Science, 2000 - pubsonline.informs.org
# LINK    : https://pubsonline.informs.org/doi/abs/10.1287/mnsc.46.2.302.11930
#
#
# TITLE   : Characterizing search spaces for tabu search and including adaptive memory into a genetic algorithm
# AUTHORS : JA Joines, CR Houck, MG Kay - Journal of the Chinese Institute of …, 2000 - Taylor & Francis
# LINK    : https://www.tandfonline.com/doi/abs/10.1080/10170669.2000.10432873
#
#
# TITLE   : A multiobjective genetic algorithm for the class/teacher timetabling problem
# AUTHORS : MP Carrasco, MV Pato - International Conference on the Practice and …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/3-540-44629-X_1
#
#
# TITLE   : Rescaled simulated annealing—accelerating convergence of simulated annealing by rescaling the states energies
# AUTHORS : L Herault - Journal of Heuristics, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1009627527067
#
#
# TITLE   : A parallel tabu search based method for reconfigurations of distribution systems
# AUTHORS : H Mori, Y Ogita - 2000 Power Engineering Society Summer …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/867414/
#
#
# TITLE   : [PDF][PDF] Adaptive search heuristics for the generalized assignment problem
# AUTHORS : HR Lourenço, D Serra - Mathware & Soft Computing, 2000 - econ.upf.edu
# LINK    : https://econ.upf.edu/~ramalhin/PDFfiles/2002_MSC.pdf
#
#
# TITLE   : [PDF][PDF] Diseño de metaheuristicos para problemas de rutas con flota heterogenea: concentracion heuristica
# AUTHORS : JA Pacheco, CRD Serna - Estudios de economia aplicada, 2000 - redalyc.org
# LINK    : https://www.redalyc.org/pdf/301/30114103.pdf
#
#
# TITLE   : [CITATION][C] An Effective Hybrid Optimization Approach for Dynamic Production Scheduling Problems
# AUTHORS : J Yang, L Yao - 2000 - Society of Manufacturing Engineers
# LINK    : javascript:void(0)
#
#
# TITLE   : [HTML][HTML] Analysis of solution space-dependent performance of simulated annealing: the case of the multi-level capacitated lot sizing problem
# AUTHORS : G Barbarosoğlu, L Özdamar - Computers & Operations Research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0305054899000647
#
#
# TITLE   : M-PAES: A memetic algorithm for multiobjective optimization
# AUTHORS : JD Knowles, DW Corne - … of the 2000 Congress on Evolutionary …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/870313/
#
#
# TITLE   : A genetic algorithm for FMS part type selection and machine loading
# AUTHORS : N Kumar, K Shanker - International Journal of Production Research, 2000 - Taylor & Francis
# LINK    : https://www.tandfonline.com/doi/abs/10.1080/00207540050176058
#
#
# TITLE   : [PDF][PDF] Solving large binary quadratic programming problems by effective genetic local search algorithm
# AUTHORS : K Katayama, M Tani, H Narihisa - Proceedings of the 2nd Annual …, 2000 - gpbib.cs.ucl.ac.uk
# LINK    : http://gpbib.cs.ucl.ac.uk/gecco2000/RW070.pdf
#
#
# TITLE   : [HTML][HTML] Solving the pickup and delivery problem with time windows using reactive tabu search
# AUTHORS : WP Nanry, JW Barnes - Transportation Research Part B: Methodological, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0191261599000168
#
#
# TITLE   : Constructing an Autonomous Agent with an Interdependent Heuristics
# AUTHORS : K Moriyama, M Numao - Pacific Rim International Conference on Artificial …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/3-540-44533-1_35
#
#
# TITLE   : A multiobjective genetic algorithm for radio network optimization
# AUTHORS : H Meunier, EG Talbi, P Reininger - Proceedings of the 2000 …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/870312/
#
#
# TITLE   : A tabu search heuristic for the capacitated arc routing problem
# AUTHORS : A Hertz, G Laporte, M Mittaz - Operations research, 2000 - pubsonline.informs.org
# LINK    : https://pubsonline.informs.org/doi/abs/10.1287/opre.48.1.129.12455
#
#
# TITLE   : [HTML][HTML] Tabu search for DNA sequencing with false negatives and false positives
# AUTHORS : J Błażewicz, P Formanowicz, M Kasprzak… - European Journal of …, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799004567
#
#
# TITLE   : Heuristics
# AUTHORS : B Fortz, B Fortz - Design of Survivable Networks with Bounded Rings, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-1-4615-4669-6_7
#
#
# TITLE   : Island model cooperating with speciation for multimodal optimization
# AUTHORS : M Bessaou, A Pétrowski, P Siarry - … Problem Solving from Nature PPSN VI …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/3-540-45356-3_43
#
#
# TITLE   : An ant algorithm with a new pheromone evaluation rule for total tardiness problems
# AUTHORS : D Merkle, M Middendorf - … EvoRob, and EvoFlight Edinburgh, Scotland, UK …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/3-540-45561-2_28
#
#
# TITLE   : [HTML][HTML] Routing and wavelength assignment with power considerations in optical networks
# AUTHORS : M Ali, B Ramamurthy, JS Deogun - Computer Networks, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S1389128600000153
#
#
# TITLE   : [PDF][PDF] Maximizing net present value for generalized resource constrained project scheduling problem
# AUTHORS : E Goto, T Joko, K Fujisawa, N Katoh… - … Institute, Tokyo, Japan, 2000 - researchgate.net
# LINK    : https://www.researchgate.net/profile/Katsuki-Fujisawa/publication/241066535_Maximizing_Net_Present_Value_for_Generalized_Resource_Constrained_Project_Scheduling_Problem/links/55b4c1cf08ae9289a08a4ac0/Maximizing-Net-Present-Value-for-Generalized-Resource-Constrained-Project-Scheduling-Problem.pdf
#
#
# TITLE   : [PDF][PDF] A Multiple-Choce Genetic Algorithm for a Nonlinear Cutting Stock Problem
# AUTHORS : JC Bean - Computing in Science and Engineering, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/iel5/5992/17882/x0267600.pdf
#
#
# TITLE   : [HTML][HTML] Modelling multi-stage manufacturing systems for efficient scheduling
# AUTHORS : C Charalambous, T Tahmassebi, K Hindi - European Journal of …, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799002362
#
#
# TITLE   : [HTML][HTML] Service network design in freight transportation
# AUTHORS : TG Crainic - European journal of operational research, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377221799002337
#
#
# TITLE   : [HTML][HTML] Ant algorithms
# AUTHORS : M Dorigo, G Di Caro, T Stützle - Future Generation Computer Systems, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0167739X00000418
#
#
# TITLE   : The optimization of number of kanbans with genetic algorithms, simulated annealing and tabu search
# AUTHORS : C Alabas, F Altiparmak, B Dengiz - Proceedings of the 2000 …, 2000 - ieeexplore.ieee.org
# LINK    : https://ieeexplore.ieee.org/abstract/document/870349/
#
#
# TITLE   : Approximation algorithms for scheduling problems
# AUTHORS : H Ishii, M Tada - IEICE TRANSACTIONS on Information and …, 2000 - search.ieice.org
# LINK    : https://search.ieice.org/bin/summary.php?id=e83-d_3_496
#
#
# TITLE   : [HTML][HTML] Recent developments and trends in global optimization
# AUTHORS : PM Pardalos, HE Romeijn, H Tuy - Journal of computational and Applied …, 2000 - Elsevier
# LINK    : https://www.sciencedirect.com/science/article/pii/S0377042700004258
#
#
# TITLE   : [PDF][PDF] A memetic algorithm with self-adaptive local search: TSP as a case study
# AUTHORS : N Krasnogor, J Smith - … of the 2nd annual conference on …, 2000 - gpbib.pmacs.upenn.edu
# LINK    : https://gpbib.pmacs.upenn.edu/gecco2000/SC172.pdf
#
#
# TITLE   : Heuristic concentration: a study of stage one
# AUTHORS : KE Rosing - Environment and Planning B: Planning and …, 2000 - journals.sagepub.com
# LINK    : https://journals.sagepub.com/doi/abs/10.1068/b2526
#
#
# TITLE   : [HTML][HTML] Cycle location problems
# AUTHORS : IR Martín - 2000 - search.proquest.com
# LINK    : https://search.proquest.com/openview/5318c6de2925225df7b6b5c686e748c3/1?pq-origsite=gscholar&cbl=2026366&diss=y
#
#
# TITLE   : [CITATION][C] A co-evolutionist meta-heuristic for the FAP
# AUTHORS : B Weinberg, V Bachelet, G Talbi - Frequency Assignment Workshop, London …, 2000
# LINK    : javascript:void(0)
#
#
# TITLE   : [PDF][PDF] Multi objective decision making-Solutions for the optimization of manufacturing processes
# AUTHORS : G Weigert, S Werner, D Hampel, H Heinrich… - Proceedings of the 10th …, 2000 - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=0dca9ef4fe0b9c0a37e66657a434dca2e96d9969
#
#
# TITLE   : [PDF][PDF] Tabu search for multiobjective combinatorial optimization: TAMOCO
# AUTHORS : M Hansen - Control and Cybernetics, 2000 - bibliotekanauki.pl
# LINK    : https://bibliotekanauki.pl/articles/205565.pdf

# %%
# Generate 10 unique random indexes between 0 and NB_PAGES_TO_SCRAPE * 10 - 1
index_max = NB_PAGES_TO_SCRAPE * 10 - 1
indexes = np.random.randint(0, index_max, size=(NB_ARTICLES,))
while len(set(indexes)) != len(indexes):
  indexes = np.random.randint(0, index_max, size=(NB_ARTICLES,))

# Display articles
for i in indexes:
  print(f"TITLE   : {articles[i]['title']}\n"
        f"AUTHORS : {articles[i]['authors']}\n"
        f"LINK    : {articles[i]['link']}\n\n")
# Out:
# TITLE   : Applying combinatorial optimization metaheuristics to the golf scramble problem
# AUTHORS : RG Dear, Z Drezner - International Transactions in Operational …, 2000 - Wiley Online Library
# LINK    : https://onlinelibrary.wiley.com/doi/abs/10.1111/j.1475-3995.2000.tb00203.x
#
#
# TITLE   : Metaheuristic methods for a class of the facility layout problem
# AUTHORS : A Gomes de Alvarenga, FJ Negreiros-Gomes… - Journal of intelligent …, 2000 - Springer
# LINK    : https://link.springer.com/article/10.1023/A:1008982420344
#
#
# TITLE   : [PDF][PDF] On metaheuristic algorithms for combinatorial optimization problems
# AUTHORS : M Yagiura, T Ibaraki - The Transactions of the Institute of Electronics …, 2000 - Citeseer
# LINK    : https://citeseerx.ist.psu.edu/document?repid=rep1&type=pdf&doi=9b8ed5e5f89868c14b1ef6d3b1da7084f3878d9b
#
#
# TITLE   : Optimization of a simplified fleet assignment problem with metaheuristics: Simulated annealing and GRASP
# AUTHORS : D Sosnowska - … and Complexity in Numerical Optimization: Continuous …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-1-4757-3145-3_27
#
#
# TITLE   : Solving general ring network design problems by meta-heuristics
# AUTHORS : A Fink, G Schneidereit, S Voß - Computing Tools for Modeling …, 2000 - Springer
# LINK    : https://link.springer.com/chapter/10.1007/978-1-4615-4567-5_5

# %%
download_articles(articles)
